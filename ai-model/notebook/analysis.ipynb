# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\PC\Documents\GitHub\sudo-visign\data\cleaned_data.csv')

# %%
df.head()
# Out:
#    ID    TOPIC        LABEL                                          VIDEO_URL
# 0   1  Câu hỏi     bao giờ?  https://player.vimeo.com/video/674716358?badge...
# 1   2  Câu hỏi   bao nhiêu?  https://player.vimeo.com/video/674716255?badge...
# 2   3  Câu hỏi  có … không?  https://player.vimeo.com/video/663287057?badge...
# 3   4  Câu hỏi     còn bạn?  https://player.vimeo.com/video/663369409?badge...
# 4   5  Câu hỏi   đẹp không?  https://player.vimeo.com/video/664743761?badge...

# %%
filtered_df = df[df['TOPIC'].isin(['Đồ vật', 'Hành động'])].reset_index(drop=True)
filtered_df['ID'] = range(1, len(filtered_df) + 1)
filtered_df
# Out:
#     ID      TOPIC                   LABEL  \
# 0    1     Đồ vật             ấm đun nước
# 1    2     Đồ vật      bàn chải đánh răng
# 2    3     Đồ vật                  bàn là
# 3    4     Đồ vật                  bản lề
# 4    5     Đồ vật  bàn phím (máy vi tính)
# ..  ..        ...                     ...
# 88  89  Hành động                     cấy
# 89  90  Hành động                 cấy lúa
# 90  91  Hành động               cày ruộng
# 91  92  Hành động                    chào
# 92  93  Hành động                 chào cờ
#
#                                             VIDEO_URL
# 0   https://player.vimeo.com/video/670183397?badge...
# 1   https://player.vimeo.com/video/661096392?badge...
# 2   https://player.vimeo.com/video/674508995?badge...
# 3   https://player.vimeo.com/video/674519230?badge...
# 4   https://player.vimeo.com/video/674508918?badge...
# ..                                                ...
# 88  https://player.vimeo.com/video/675874958?badge...
# ...

# %%
filtered_df = filtered_df.drop(columns=['VIDEO_URL'])

# %%
filtered_df.to_csv(r'C:\Users\PC\Documents\GitHub\sudo-visign\data\filtered_topics_data.csv', index=False)
